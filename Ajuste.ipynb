# %%
import pandas as pd

# %%
df = pd.read_excel('saldo_pessoal_n.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1                     Unnamed: 2  \
# 0         NaN         UO                   DESCRICAO_UO
# 1         NaN      11006                 GABINETE CIVIL
# 2         NaN      11008  CONTROLADORIA GERAL DO ESTADO
# 3         NaN      11009   PROCURADORIA GERAL DO ESTADO
# 4         NaN      11013    GABINETE DO VICE-GOVERNADOR
#
#               Unnamed: 3        Unnamed: 4       Unnamed: 5  \
# 0  VALOR_DOTACAO_INICIAL  VALOR_ATUALIZADO  VALOR_EMPENHADO
# 1               17568076          17568076      14221393.28
# 2                3547386           3547386        2258167.9
# 3               60899473          60899473      45065037.36
# 4                1923628           1913628       1708194.99
#
#                      Unnamed: 6       Unnamed: 7      Unnamed: 8
# 0  previsão 4 quadrimestre 2024       total 2024           saldo
# 1                6204477.075908  20425870.355908 -2857794.355908
# 2                1197061.185824   3455229.085824    92156.914176
# ...

# %%
# dropar primeira cioluna
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL  \
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL
# 1  11006                 GABINETE CIVIL               17568076
# 2  11008  CONTROLADORIA GERAL DO ESTADO                3547386
# 3  11009   PROCURADORIA GERAL DO ESTADO               60899473
# 4  11013    GABINETE DO VICE-GOVERNADOR                1923628
#
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO  previsão 4 quadrimestre 2024  \
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO  previsão 4 quadrimestre 2024
# 1          17568076      14221393.28                6204477.075908
# 2           3547386        2258167.9                1197061.185824
# 3          60899473      45065037.36                22930738.08049
# 4           1913628       1708194.99                 1044303.05133
#
# 0       total 2024           saldo
# 0       total 2024           saldo
# 1  20425870.355908 -2857794.355908
# 2   3455229.085824    92156.914176
# 3   67995775.44049  -7096302.44049
# ...

# %%
df.tail()
# Out:
# 0            UO                                       DESCRICAO_UO  \
# 61        41516         BANCO DO ESTADO DE ALAGOAS EM LIQUIDAÇÃO\t
# 62        91997  ENCARGOS GERAIS DO ESTADO - RECURSOS SOB SUPER...
# 63  Total geral                                                NaN
# 64          NaN                                                NaN
# 65          NaN                                                NaN
#
# 0  VALOR_DOTACAO_INICIAL VALOR_ATUALIZADO VALOR_EMPENHADO  \
# 61                 50000            50000           50000
# 62             255466792        255466792     94193879.15
# 63         7190088439.44    7243216793.17   5071932037.82
# 64                   NaN              NaN    838795602.99
# 65                   NaN              NaN   4230860682.25
#
# 0  previsão 4 quadrimestre 2024        total 2024             saldo
# 61                        25000             50000                 0
# 62              64004001.453558  158197880.603558   97268911.396442
# ...

# %%
# Dropar ultimas 3 linhas
df.drop(df.tail(3).index, inplace=True)

# %%
df.head()
# Out:
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL  \
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL
# 1  11006                 GABINETE CIVIL               17568076
# 2  11008  CONTROLADORIA GERAL DO ESTADO                3547386
# 3  11009   PROCURADORIA GERAL DO ESTADO               60899473
# 4  11013    GABINETE DO VICE-GOVERNADOR                1923628
#
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO  previsão 4 quadrimestre 2024  \
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO  previsão 4 quadrimestre 2024
# 1          17568076      14221393.28                6204477.075908
# 2           3547386        2258167.9                1197061.185824
# 3          60899473      45065037.36                22930738.08049
# 4           1913628       1708194.99                 1044303.05133
#
# 0       total 2024           saldo
# 0       total 2024           saldo
# 1  20425870.355908 -2857794.355908
# 2   3455229.085824    92156.914176
# 3   67995775.44049  -7096302.44049
# ...

# %%
df.tail()
# Out:
# 0      UO                                       DESCRICAO_UO  \
# 58  36021  SECRETARIA DE ESTADO DO ESPORTE, LAZER E JUVEN...
# 59  37001                    SECRETARIA DE ESTADO DE GOVERNO
# 60  38001          SECRETARIA DE ESTADO DA PRIMEIRA INFANCIA
# 61  41516         BANCO DO ESTADO DE ALAGOAS EM LIQUIDAÇÃO\t
# 62  91997  ENCARGOS GERAIS DO ESTADO - RECURSOS SOB SUPER...
#
# 0  VALOR_DOTACAO_INICIAL VALOR_ATUALIZADO VALOR_EMPENHADO  \
# 58               2795473          2795473      1740385.49
# 59              24315888         22437050     16088153.55
# 60                     0          1878838      1575810.53
# 61                 50000            50000           50000
# 62             255466792        255466792     94193879.15
#
# 0  previsão 4 quadrimestre 2024        total 2024            saldo
# 58                952080.070857    2692465.560857    103007.439143
# 59                  8044076.775      24132230.325     -1695180.325
# ...

# %%
# rename columns 
df.rename(columns={'previsão 4 quadrimestre 2024': 'PREVISAO'}, inplace=True)
df.rename(columns={'total 2024': 'TOTAL'}, inplace=True)
df.rename(columns={'saldo': 'SALDO'}, inplace=True)

# %%
df.head()
# Out:
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL  \
# 0     UO                   DESCRICAO_UO  VALOR_DOTACAO_INICIAL
# 1  11006                 GABINETE CIVIL               17568076
# 2  11008  CONTROLADORIA GERAL DO ESTADO                3547386
# 3  11009   PROCURADORIA GERAL DO ESTADO               60899473
# 4  11013    GABINETE DO VICE-GOVERNADOR                1923628
#
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO                      PREVISAO  \
# 0  VALOR_ATUALIZADO  VALOR_EMPENHADO  previsão 4 quadrimestre 2024
# 1          17568076      14221393.28                6204477.075908
# 2           3547386        2258167.9                1197061.185824
# 3          60899473      45065037.36                22930738.08049
# 4           1913628       1708194.99                 1044303.05133
#
# 0            TOTAL           SALDO
# 0       total 2024           saldo
# 1  20425870.355908 -2857794.355908
# 2   3455229.085824    92156.914176
# 3   67995775.44049  -7096302.44049
# ...

# %%
# dropar linha 0
df.drop(df.head(1).index, inplace=True)

# %%
df.head()
# Out:
# 0     UO                                    DESCRICAO_UO  \
# 1  11006                                  GABINETE CIVIL
# 2  11008                   CONTROLADORIA GERAL DO ESTADO
# 3  11009                    PROCURADORIA GERAL DO ESTADO
# 4  11013                     GABINETE DO VICE-GOVERNADOR
# 5  11015  SECRETARIA DE ESTADO DE GOVERNANÇA CORPORATIVA
#
# 0 VALOR_DOTACAO_INICIAL VALOR_ATUALIZADO VALOR_EMPENHADO        PREVISAO  \
# 1              17568076         17568076     14221393.28  6204477.075908
# 2               3547386          3547386       2258167.9  1197061.185824
# 3              60899473         60899473     45065037.36  22930738.08049
# 4               1923628          1913628      1708194.99   1044303.05133
# 5               1878838          1878838      1152910.72       576455.36
#
# 0            TOTAL           SALDO
# 1  20425870.355908 -2857794.355908
# 2   3455229.085824    92156.914176
# 3   67995775.44049  -7096302.44049
# 4    2752498.04133   -838870.04133
# ...

# %%
df.to_csv('data/SALDO_PESSOAL.csv', index=False)
